# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import os

# %%
os.path.isfile('서울시_강우량_정보_2024년05월.csv')
# Out:
# True

# %%
df=pd.read_csv('/practice/서울시_강우량_정보_2024년05월.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df=pd.read_csv('practice'/'서울시_강우량_정보_2024년05월.csv')
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'c:\\Users\\dh002\\OneDrive\\practice': ['seoul_rain5.ipynb', '서울시_강우량_정보_2024년05월.csv']

# %%
f = open('c:\\Users\\dh002\\OneDrive\\practice\\서울시_강우량_정보_2024년05월.csv')

# %%
f
# Out:
# <_io.TextIOWrapper name='c:\\Users\\dh002\\OneDrive\\practice\\서울시_강우량_정보_2024년05월.csv' mode='r' encoding='cp949'>

# %%
df=pd.read_csv('c:\\Users\\dh002\\OneDrive\\practice\\서울시_강우량_정보_2024년05월.csv', encoding='cp949')

# %%
df
# Out:
#         강우량계 코드 강우량계명  구청 코드  구청명  10분우량           자료수집 시각
# 0           202  고덕2동    102  강동구    0.0  2024-05-01 00:09
# 1          1801  양천구청    118  양천구    0.0  2024-05-01 00:09
# 2          2001  구로구청    120  구로구    0.0  2024-05-01 00:09
# 3           301  도봉구청    103  도봉구    0.0  2024-05-01 00:09
# 4          1701  강서구청    117  강서구    0.0  2024-05-01 00:09
# ...         ...   ...    ...  ...    ...               ...
# 213315      601  성북구청    106  성북구    0.0  2024-05-31 23:59
# 213316     2201  금천구청    122  금천구    0.0  2024-05-31 23:59
# 213317      702   면목P    107  중랑구    0.0  2024-05-31 23:59
# 213318     2101  동작구청    121  동작구    0.0  2024-05-31 23:59
# 213319      101  강남구청    101  강남구    0.0  2024-05-31 23:59
#
# [213320 rows x 6 columns]

# %%
grouped=df.groupby(df['강우량계 코드'])

# %%
grouped.head()
# Out:
#      강우량계 코드  강우량계명  구청 코드   구청명  10분우량           자료수집 시각
# 0        202   고덕2동    102   강동구    0.0  2024-05-01 00:09
# 1       1801   양천구청    118   양천구    0.0  2024-05-01 00:09
# 2       2001   구로구청    120   구로구    0.0  2024-05-01 00:09
# 3        301   도봉구청    103   도봉구    0.0  2024-05-01 00:09
# 4       1701   강서구청    117   강서구    0.0  2024-05-01 00:09
# ..       ...    ...    ...   ...    ...               ...
# 235     1601   용산구청    116   용산구    0.0  2024-05-01 00:49
# 236     1401  서대문구청    114  서대문구    0.0  2024-05-01 00:49
# 237     2001   구로구청    120   구로구    0.0  2024-05-01 00:49
# 238     1502    봉원P    115   마포구    0.0  2024-05-01 00:49
# 239     1802    목동P    118   양천구    0.0  2024-05-01 00:49
#
# [240 rows x 6 columns]

# %%
for name, grouped in df.groupby('강우량계 코드'):
    print(name)
    print(grouped)
# Out:
# 101
#         강우량계 코드 강우량계명  구청 코드  구청명  10분우량           자료수집 시각
# 33          101  강남구청    101  강남구    0.0  2024-05-01 00:09
# 72          101  강남구청    101  강남구    0.0  2024-05-01 00:19
# 101         101  강남구청    101  강남구    0.0  2024-05-01 00:29
# 154         101  강남구청    101  강남구    0.0  2024-05-01 00:39
# 194         101  강남구청    101  강남구    0.0  2024-05-01 00:49
# ...         ...   ...    ...  ...    ...               ...
# 213087      101  강남구청    101  강남구    0.0  2024-05-31 23:19
# 213145      101  강남구청    101  강남구    0.0  2024-05-31 23:29
# 213220      101  강남구청    101  강남구    0.0  2024-05-31 23:39
# 213266      101  강남구청    101  강남구    0.0  2024-05-31 23:49
# 213319      101  강남구청    101  강남구    0.0  2024-05-31 23:59
#
# [4459 rows x 6 columns]
# 102
#         강우량계 코드 강우량계명  구청 코드  구청명  10분우량           자료수집 시각
# 5           102   세곡동    101  강남구    0.0  2024-05-01 00:09
# 56          102   세곡동    101  강남구    0.0  2024-05-01 00:19
# ...

# %%
for name, grouped in df.groupby('강우량계명'):
        print(name)
        print(grouped)
# Out:
# 가산2P
#         강우량계 코드 강우량계명  구청 코드  구청명  10분우량           자료수집 시각
# 11         2202  가산2P    122  금천구    0.0  2024-05-01 00:09
# 66         2202  가산2P    122  금천구    0.0  2024-05-01 00:19
# 111        2202  가산2P    122  금천구    0.0  2024-05-01 00:29
# 150        2202  가산2P    122  금천구    0.0  2024-05-01 00:39
# 213        2202  가산2P    122  금천구    0.0  2024-05-01 00:49
# ...         ...   ...    ...  ...    ...               ...
# 213124     2202  가산2P    122  금천구    0.0  2024-05-31 23:19
# 213136     2202  가산2P    122  금천구    0.0  2024-05-31 23:29
# 213195     2202  가산2P    122  금천구    0.0  2024-05-31 23:39
# 213243     2202  가산2P    122  금천구    0.0  2024-05-31 23:49
# 213294     2202  가산2P    122  금천구    0.0  2024-05-31 23:59
#
# [4459 rows x 6 columns]
# 갈현1동
#         강우량계 코드 강우량계명  구청 코드  구청명  10분우량           자료수집 시각
# 47         1303  갈현1동    113  은평구    0.0  2024-05-01 00:09
# 62         1303  갈현1동    113  은평구    0.0  2024-05-01 00:19
# ...

# %%
for name, grouped in df.groupby('강우량계 코드'):
    print(name)
    print(grouped)

# %%
avg_seoul_5=df.groupby('강우량계 코드').mean('10분우량')

# %%
avg_seoul_5
# Out:
#          구청 코드     10분우량
# 강우량계 코드
# 101      101.0  0.024669
# 102      101.0  0.025517
# 103      101.0  0.022819
# 201      102.0  0.021417
# 202      102.0  0.022427
# 301      103.0  0.032294
# 401      104.0  0.028831
# 402      104.0  0.030949
# 501      105.0  0.027248
# 601      106.0  0.027473
# 602      106.0  0.028930
# 701      107.0  0.022987
# 702      107.0  0.024445
# 801      108.0  0.025254
# 802      108.0  0.024036
# 901      109.0  0.023996
# 902      109.0  0.023772
# 1001     110.0  0.026800
# 1002     110.0  0.031061
# 1101     111.0  0.026688
# 1104     111.0  0.024781
# 1201     112.0  0.025670
# 1301     113.0  0.025454
# 1302     113.0  0.024893
# 1303     113.0  0.025903
# 1401     114.0  0.029267
# 1501     115.0  0.026127
# 1502     115.0  0.027136
# 1601     116.0  0.023772
# 1602     116.0  0.023436
# 1701     117.0  0.025678
# 1702     117.0  0.024899
# 1801     118.0  0.025230
# 1802     118.0  0.025678
# 1901     119.0  0.024030
# ...

# %%
avg_seoul_5_filterd=avg_seoul_5[avg_seoul_5['구청 코드']==101.0]

# %%
avg_seoul_5_filterd
# Out:
#          구청 코드     10분우량
# 강우량계 코드
# 101      101.0  0.024669
# 102      101.0  0.025517
# 103      101.0  0.022819

# %%
sns.countplot(x='구청 코드', data=avg_seoul_5, color='red')
# Out:
# <Axes: xlabel='구청 코드', ylabel='count'>
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.scatterplot(x='구청 코드', y='10분우량', data=avg_seoul_5_filterd)
plt.title('my execercise')
# Out:
# Text(0.5, 1.0, 'my execercise')
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Python\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
avg_seoul_5_grouped=avg_seoul_5.groupby('구청 코드')

# %%
avg_seoul_5_grouped

# %%
#matplotlib에서 한글 지원 안 해줘서 오류발생.. 이 코드를 입력해야 글자가 깨지지 않는다ㅜ

import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
sns.scatterplot(x='구청 코드', y='10분우량', data=avg_seoul_5)
plt.title('서울시 5월 구청 코드 별 10분 우량')
plt.xlabel('구청코드')
plt.ylabel('10분 우량')
plt.show()
