# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import os

# %%
os.path.isfile('test-file.csv')
# Out:
# True

# %%
star=pd.read_excel('dataesets/star/star.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 star=pd.read_excel('dataesets/star/star.xlsx')
#
# File c:\Python\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
census=pd.read_csv('datasets/census/census.csv')

# %%
census
# Out:
#        state  year  population  land_area
# 0    Alabama  2010     4785437      52420
# 1    Alabama  2011     4799069      52420
# 2    Alabama  2012     4815588      52420
# 3    Alabama  2013     4830081      52420
# 4    Alabama  2014     4841799      52420
# ..       ...   ...         ...        ...
# 301  Wyoming  2011      567299      97813
# 302  Wyoming  2012      576305      97813
# 303  Wyoming  2013      582122      97813
# 304  Wyoming  2014      582531      97813
# 305  Wyoming  2015      585613      97813
#
# [306 rows x 4 columns]

# %%
census=pd.read_csv('datasets/census/census-divisions.csv')

# %%
census
# Out:
#                    state postal_code     region            division
# 0            Connecticut          CT  Northeast         New England
# 1                  Maine          ME  Northeast         New England
# 2          Massachusetts          MA  Northeast         New England
# 3          New Hampshire          NH  Northeast         New England
# 4           Rhode Island          RI  Northeast         New England
# 5                Vermont          VT  Northeast         New England
# 6             New Jersey          NJ  Northeast     Middle Atlantic
# 7               New York          NY  Northeast     Middle Atlantic
# 8           Pennsylvania          PA  Northeast     Middle Atlantic
# 9               Illinois          IL    Midwest  East North Central
# 10               Indiana          IN    Midwest  East North Central
# 11              Michigan          MI    Midwest  East North Central
# 12                  Ohio          OH    Midwest  East North Central
# ...

# %%
census_pivot=pd.melt(frame=census, id_vars='state', value_vars=['state','state'],value_name='state', var_name='state2')
census_pivot.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 census_pivot=pd.melt(frame=census, id_vars='state', value_vars=['state','state'],value_name='state', var_name='state2')
#       2 census_pivot.head()
#
# File c:\Python\Lib\site-packages\pandas\core\reshape\melt.py:54, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      43 @Appender(_shared_docs["melt"] % {"caller": "pd.melt(df, ", "other": "DataFrame.melt"})
#      44 def melt(
#      45     frame: DataFrame,
#    (...)
#      51     ignore_index: bool = True,
#      52 ) -> DataFrame:
#      53     if value_name in frame.columns:
# ---> 54         raise ValueError(
#      55             f"value_name ({value_name}) cannot match an element in "
#      56             "the DataFrame columns."
#      57         )
# ...

# %%
census2=pd.read_csv('datasets/census/census.ex2.csv')

# %%
census2
# Out:
#        state  year  population  land_area  density         state2 postal_code  \
# 0    Alabama  2010     4785437      52420    15217    Connecticut          CT
# 1    Alabama  2011     4799069      52420    28849          Maine          ME
# 2    Alabama  2012     4815588      52420    45368  Massachusetts          MA
# 3    Alabama  2013     4830081      52420     7441  New Hampshire          NH
# 4    Alabama  2014     4841799      52420    19159   Rhode Island          RI
# ..       ...   ...         ...        ...      ...            ...         ...
# 301  Wyoming  2011      567299      97813    78234            NaN         NaN
# 302  Wyoming  2012      576305      97813    87240            NaN         NaN
# 303  Wyoming  2013      582122      97813    93057            NaN         NaN
# 304  Wyoming  2014      582531      97813    93466            NaN         NaN
# 305  Wyoming  2015      585613      97813    96548            NaN         NaN
#
#         region     division
# ...

# %%
census2_filterd=census2[census2['year']==2015]
census2_filterd
# Out:
#                     state  year  population  land_area  density  \
# 5                 Alabama  2015     4852347      52420    29707
# 11                 Alaska  2015      737498     665384    72114
# 17                Arizona  2015     6829676     113990   104266
# 23               Arkansas  2015     2978048      53179       24
# 29             California  2015    38918045     163695   122330
# 35               Colorado  2015     5450623     104094    37735
# 41            Connecticut  2015     3587122       5543      801
# 47               Delaware  2015      941252       2489      410
# 53   District of Columbia  2015      675400         68       24
# 59                Florida  2015    20209042      65758    21336
# 65                Georgia  2015    10178447      59425    16772
# 71                 Hawaii  2015     1422052      10932      892
# 77                  Idaho  2015     1651059      83569    63248
# 83               Illinois  2015    12858913      57914     2005
# ...

# %%
sns.countplot(x='land_area', data=census2_filterd)
# Out:
# <Axes: xlabel='land_area', ylabel='count'>

# %%
census2_filterd_grouped=census2_filterd.groupby('land_area')
census2_filterd_grouped

# %%
sns.scatterplot(x='land_area',y='population', data=census2_filterd)
# Out:
# <Axes: xlabel='land_area', ylabel='population'>

# %%
sns.displot(x='land_area',y='population', data=census2_filterd)

# %%
sns.scatterplot(x='population', y='land_area', data=census2_filterd)
plt.title('My execercise')
# Out:
# Text(0.5, 1.0, 'My execercise')
