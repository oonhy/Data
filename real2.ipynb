# %%
import pandas as pd

# %%
import os

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'c:\\Users\\dh002\\OneDrive\\relative-performance\\relative': ['grouped_by_date.xlsx', 'real.ipynb', 'real2.ipynb', 'relative-performance.xlsx', 'x.txt']

# %%
# !pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)

# %%
f = open('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')

# %%
f
# Out:
# <_io.TextIOWrapper name='c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx' mode='r' encoding='cp949'>

# %%
df=pd.read_excel('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')

# %%
df
# Out:
#        Date Product  Performance
# 0    240701    A104           97
# 1    240701    A120          116
# 2    240701    A121          111
# 3    240701    A123          106
# 4    240701    A110           98
# ..      ...     ...          ...
# 305  240720    A115           98
# 306  240720    A113           97
# 307  240720    A109          104
# 308  240720    A117          111
# 309  240720    A114          109
#
# [310 rows x 3 columns]

# %%
grouped=df.groupby(df['Date']) #동일한 Date값을 가지는 행을 그룹으로 묶기

# %%
grouped.head()
# Out:
#        Date Product  Performance
# 0    240701    A104           97
# 1    240701    A120          116
# 2    240701    A121          111
# 3    240701    A123          106
# 4    240701    A110           98
# ..      ...     ...          ...
# 274  240719    A109          105
# 288  240720    A103          108
# 289  240720    A102           98
# 290  240720    A105          114
# 291  240720    A111           90
#
# [100 rows x 3 columns]

# %%
#그룹 간 순회하기. 그룹 이름과 그에 따른 데이터 묶음 튜플로 반환
for name, grouped in df.groupby('Date'):
    print(name)
    print(grouped)
# Out:
# 240701
#       Date Product  Performance
# 0   240701    A104           97
# 1   240701    A120          116
# 2   240701    A121          111
# 3   240701    A123          106
# 4   240701    A110           98
# 5   240701    A109          117
# 6   240701    A114          120
# 7   240701    A109           98
# 8   240701    A102          103
# 9   240701    A114          102
# 10  240701    A113          118
# 11  240701    A115           99
# 240702
#       Date Product  Performance
# 12  240702    A103           97
# 13  240702    A103           93
# 14  240702    A103           92
# 15  240702    A109          105
# 16  240702    A102          109
# 17  240702    A104           85
# 18  240702    A114           97
# 19  240702    A110          106
# 20  240702    A117           81
# 21  240702    A102           86
# 22  240702    A105          113
# 23  240702    A118          118
# 24  240702    A120           92
# 25  240702    A120          114
# ...

# %%
Product=df.groupby('Date')['Product'] #튜플 안의 자료를 변수로 선언했음

# %%
Performance=df.groupby('Date')['Performance']

# %%
relative1=[]

def relative_value(df, ref, max_level):
    df=pd.read_excel('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')
    
    for name, grouped in df.groupby('Date'):
        print(name)
        print(grouped)
        if 'A100' in df:
            df['A100']=ref
            if len('A100')>1:

                df.insert(loc=1, column='Date2', value=df['A100'])
                list_ref=[]
                list_ref.append(df['A100'])
        else: 
            relative2=[]
            relative2.append(ref)

# %%
print(relative_value)
# Out:
# <function relative_value at 0x000002133731B100>

# %%
for idx, row in df.iterrows():
    print(idx)
    print(row['Date'])
    print(row['Product'])
    print(row['Performance'])
# Out:
# 0
# 240701
# A104
# 97
# 1
# 240701
# A120
# 116
# 2
# 240701
# A121
# 111
# 3
# 240701
# A123
# 106
# 4
# 240701
# A110
# 98
# 5
# 240701
# A109
# 117
# 6
# 240701
# A114
# 120
# 7
# 240701
# A109
# 98
# 8
# 240701
# A102
# 103
# 9
# 240701
# A114
# 102
# 10
# 240701
# A113
# 118
# 11
# 240701
# A115
# 99
# 12
# 240702
# A103
# 97
# 13
# 240702
# A103
# 93
# 14
# 240702
# A103
# 92
# 15
# 240702
# A109
# 105
# 16
# 240702
# A102
# 109
# 17
# 240702
# A104
# 85
# 18
# 240702
# A114
# 97
# 19
# 240702
# A110
# 106
# 20
# 240702
# A117
# 81
# 21
# 240702
# A102
# 86
# 22
# 240702
# A105
# 113
# 23
# 240702
# A118
# 118
# 24
# 240702
# A120
# 92
# 25
# 240702
# A120
# 114
# 26
# 240702
# A108
# 97
# 27
# 240703
# A105
# 109
# 28
# 240703
# A101
# 98
# 29
# 240703
# A102
# 99
# 30
# 240703
# A113
# 109
# 31
# 240703
# A104
# 108
# 32
# 240703
# A118
# 101
# 33
# 240703
# A109
# 93
# 34
# 240703
# A109
# 104
# 35
# 240703
# A104
# 114
# 36
# 240703
# A113
# 106
# 37
# 240703
# A109
# 96
# ...

# %%
#원하는 데이터를 찾기
standard=dict(list(df.groupby('Date')))

# %%
standard['A100']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 standard['A100']
#
# KeyError: 'A100'

# %%
def relative_value(df, ref, max_level):
    df=pd.read_excel('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')
    if ref==[['A100']]
# Out:
#   Cell In[20], line 1
#     def comparison(df, ref, max_level):
#                                        ^
# SyntaxError: incomplete input

# %%
Product=df.groupby('Date')['Product']

# %%
Product.head()
# Out:
# 0      A104
# 1      A120
# 2      A121
# 3      A123
# 4      A110
#        ...
# 274    A109
# 288    A103
# 289    A102
# 290    A105
# 291    A111
# Name: Product, Length: 100, dtype: object

# %%
Performance=df.groupby('Date')['Performance']

# %%
Performance.head()
# Out:
# 0       97
# 1      116
# 2      111
# 3      106
# 4       98
#       ...
# 274    105
# 288    108
# 289     98
# 290    114
# 291     90
# Name: Performance, Length: 100, dtype: int64

# %%
def select_ref(Product, Performance):
    if Product=='A100':
        Product=ref
    
    else: ref=Performance/100

# %%
relative1=[]

def relative_value(df, ref, max_level):
    df=pd.read_excel('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')
    def select_ref(Product, Performance):
        if Product=='A100'in df:
            Product=ref
            
        else: ref=Performance/100

    # ref의 performance와 다른 standard의 performance를 비교하는 코드 작성하기
# Out:
#   Cell In[42], line 13
#
#     ^
# SyntaxError: incomplete input

# %%
 df=pd.read_excel('c:\\Users\\dh002\\OneDrive\\relative-performance\\relative\\relative-performance.xlsx')

# %%
df
# Out:
#        Date Product  Performance
# 0    240701    A104           97
# 1    240701    A120          116
# 2    240701    A121          111
# 3    240701    A123          106
# 4    240701    A110           98
# ..      ...     ...          ...
# 305  240720    A115           98
# 306  240720    A113           97
# 307  240720    A109          104
# 308  240720    A117          111
# 309  240720    A114          109
#
# [310 rows x 3 columns]

# %%
grouped=df.groupby(df['Date'])

# %%
for name, group in df.groupby('Date'):
    print(name)
    print(group)
# Out:
# 240701
#       Date Product  Performance
# 0   240701    A104           97
# 1   240701    A120          116
# 2   240701    A121          111
# 3   240701    A123          106
# 4   240701    A110           98
# 5   240701    A109          117
# 6   240701    A114          120
# 7   240701    A109           98
# 8   240701    A102          103
# 9   240701    A114          102
# 10  240701    A113          118
# 11  240701    A115           99
# 240702
#       Date Product  Performance
# 12  240702    A103           97
# 13  240702    A103           93
# 14  240702    A103           92
# 15  240702    A109          105
# 16  240702    A102          109
# 17  240702    A104           85
# 18  240702    A114           97
# 19  240702    A110          106
# 20  240702    A117           81
# 21  240702    A102           86
# 22  240702    A105          113
# 23  240702    A118          118
# 24  240702    A120           92
# 25  240702    A120          114
# ...
