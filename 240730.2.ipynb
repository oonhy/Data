# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
from sklearn import linear_model

# %%
# !pip install scipy
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Python\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'

# %%
# !pip install scikit-learn
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Python\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'

# %%
from sklearn import liner_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 from sklearn import liner_model
#
# ImportError: cannot import name 'liner_model' from 'sklearn' (c:\Python\Lib\site-packages\sklearn\__init__.py)

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn import liner_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from sklearn import liner_model
#
# ImportError: cannot import name 'liner_model' from 'sklearn' (c:\Python\Lib\site-packages\sklearn\__init__.py)

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[30], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 495.5 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/1.8 MB 550.5 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.8 MB 585.1 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.8 MB 595.3 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.8 MB 568.9 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.8 MB 579.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.8 MB 590.8 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.8 MB 573.4 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.8 MB 580.1 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/1.8 MB 568.9 kB/s eta 0:00:03
# ...

# %%
from sklearn import linear_model

# %%
from sklearn import model_selection

# %%
from sklearn import metrics

# %%
mpg=pd.read_csv('datasets/mpg/mpg.csv',usecols=['mpg','weight','horsepower','origin','cylinders'])

# %%
mpg
# Out:
#       mpg  cylinders  horsepower  weight  origin
# 0    18.0          8         130    3504     USA
# 1    15.0          8         165    3693     USA
# 2    18.0          8         150    3436     USA
# 3    16.0          8         150    3433     USA
# 4    17.0          8         140    3449     USA
# ..    ...        ...         ...     ...     ...
# 387  27.0          4          86    2790     USA
# 388  44.0          4          52    2130  Europe
# 389  32.0          4          84    2295     USA
# 390  28.0          4          79    2625     USA
# 391  31.0          4          82    2720     USA
#
# [392 rows x 5 columns]

# %%
mpg.describe()
# Out:
#               mpg   cylinders  horsepower       weight
# count  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  104.469388  2977.584184
# std      7.805007    1.705783   38.491160   849.402560
# min      9.000000    3.000000   46.000000  1613.000000
# 25%     17.000000    4.000000   75.000000  2225.250000
# 50%     22.750000    4.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  126.000000  3614.750000
# max     46.600000    8.000000  230.000000  5140.000000

# %%
pd.crosstab(index=mpg['origin'], colunms='count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 pd.crosstab(index=mpg['origin'], colunms='count')
#
# TypeError: crosstab() got an unexpected keyword argument 'colunms'

# %%
pd.crosstab(index=mpg['origin'], colunms=mpg['cylinders'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 pd.crosstab(index=mpg['origin'], colunms=mpg['cylinders'])
#
# TypeError: crosstab() got an unexpected keyword argument 'colunms'

# %%
import pandas as pd

# %%
pd.crosstab(index=mpg['origin'], colunms='count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 pd.crosstab(index=mpg['origin'], colunms='count')
#
# TypeError: crosstab() got an unexpected keyword argument 'colunms'

# %%
Summary = pd.crosstab(index=mpg['origin'], columns='count')

# %%
Summary
# Out:
# col_0   count
# origin
# Asia       79
# Europe     68
# USA       245

# %%
Summary2 = pd.crosstab(index=mpg['origin'], columns=mpg['cylinders'])

# %%
Summary2
# Out:
# cylinders  3   4  5   6    8
# origin
# Asia       4  69  0   6    0
# Europe     0  61  3   4    0
# USA        0  69  0  73  103

# %%
mpg.groupby('origin').describe()['mpg']
# Out:
#         count       mean       std   min    25%   50%     75%   max
# origin
# Asia     79.0  30.450633  6.090048  18.0  25.70  31.6  34.050  46.6
# Europe   68.0  27.602941  6.580182  16.2  23.75  26.0  30.125  44.3
# USA     245.0  20.033469  6.440384   9.0  15.00  18.5  24.000  39.0

# %%
sns.displot(data=mpg,x='mpg')

# %%
sns.boxplot(x='origin', y='mpg', data=mpg, color='pink')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
usa_cars=mpg[mpg['origin']=='USA']
europe_cars=mpg[mpg['origin']=='Europe']

# %%
stats.ttest_ind(usa_cars['mpg'],europe_cars['mpg'])
# Out:
# TtestResult(statistic=np.float64(-8.534455914399228), pvalue=np.float64(6.306531719750569e-16), df=np.float64(311.0))

# %%
mpg[['mpg', 'horsepower', 'weight']].corr()
# Out:
#                  mpg  horsepower    weight
# mpg         1.000000   -0.778427 -0.832244
# horsepower -0.778427    1.000000  0.864538
# weight     -0.832244    0.864538  1.000000

# %%
sns.scatterplot(x='weight', y='mpg', data=mpg)
plt.title('Relationship between weight and mileage')
# Out:
# Text(0.5, 1.0, 'Relationship between weight and mileage')

# %%
sns.pairplot(mpg[['mpg','horsepower','weight']])

# %%
#mpg에 대한 weight의 선형회귀
stats.linregress(x=mpg['weight'], y=mpg['mpg'])
# Out:
# LinregressResult(slope=np.float64(-0.007647342535779579), intercept=np.float64(46.21652454901758), rvalue=np.float64(-0.8322442148315754), pvalue=np.float64(6.015296051435726e-102), stderr=np.float64(0.00025796327827343185), intercept_stderr=np.float64(0.7986724633128349))

# %%
#산점도에 적합 회귀선 그리기
sns.regplot(x='weight', y='mpg', data=mpg)
plt.xlabel('Weight(lbs)')
plt.ylabel('Mileage(mpg)')
plt.title('Relationship between weight and mileage')
# Out:
# Text(0.5, 1.0, 'Relationship between weight and mileage')

# %%
X_train, X_test, y_train, y_test= model_selection.train_test_split(mpg[['weight']],mpg[['mpg']],
random_state=1234)

# %%
y_train.shape
# Out:
# (294, 1)

# %%
y_test.shape
# Out:
# (98, 1)

# %%
#선형회귀 객체를 선택합니다
regr=linear_model.LinearRegression()

#학습 데이터셋을 사용하여 모델을 학습시킵니다
regr.fit(X_train, y_train)

#평가 데이터셋을 사용하여 예측하여 구합니다.
y_pred=regr.predict(X_test)

#처음 5개 관측값을 출력합니다.
y_pred[:5]
# Out:
# array([[14.86634263],
#        [23.48793632],
#        [26.2781699 ],
#        [27.69989655],
#        [29.05319785]])

# %%
regr.coef_
# Out:
# array([[-0.00760282]])

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.6811923996681357

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# np.float64(21.63348076436662)
